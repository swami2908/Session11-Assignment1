# %% [markdown]
# ## Session 11 - Assignment 1

# %% [markdown]
# #### Task 1 - Question 1 - What are the three stages to build the hypotheses or model in machine learning?

# %% [markdown]
#     Stage 1: Model building
#     Stage 2: Applying the model
#     Stage 3: Model testing

# %% [markdown]
# #### Task 1- Question 2 - What is the standard approach to supervised learning?

# %% [markdown]
# The standard approach to supervised learning is to split the set of example into the training set and the test set. Training dataset is used to train the model and test dataset is use to test the model and find accuracy for model.

# %% [markdown]
# ####  Task 1 - Question 3 - What is Training set and Test set?

# %% [markdown]
# Training set:
#
# In Machine Learning, a training set is a dataset used to train a model. In training the model, specific
# features are picked out from the training set. These features are then incorporated into the model.
# thereby, if the training set is labeled correctly, the model should be able to learn something from
# these features.
#
# In other words, the set of data which is used to discover the potentially predictive relationship is known as ‘Training Set’.
# The Training set is an examples given to the learner,
#
# Test Set:
#
# The test set is a dataset used to measure how well the model performs at making predictions on that test set.
# If the prediction scores for the test set are unreasonable, we’ll have to make some adjustments to our model and try again.
# In other words, the Test set is used to test the accuracy of the hypotheses generated by the learner, and it is the set of example held back from the learner.
#
# Also, the Training set is distinct from the Test set.

# %% [markdown]
# #### Task 1 - Question 4. What is the general principle of an ensemble method and what is bagging and boosting in ensemble method?

# %% [markdown]
# The general principle of an ensemble method is to combine the predictions of several models built with a
# given learning algorithm in order to improve robustness over a single model. Bagging is a method in ensemble for
# improving unstable estimation or classification schemes. While boosting method are used sequentially to reduce the bias of the
# combined model. Boosting and Bagging both can reduce errors by reducing the variance term.

# %% [markdown]
# #### Task 1 - Question 5. How can you avoid overfitting ?

# %% [markdown]
# Overfitting can be avoided by below mentioned methods.
# By using larger dataset overfitting can be avoided.
# If data set is small, we can use cross velidation technique to avoid overfitting.
